# %%
import numpy as np
import pandas as pd
import yfinance as yf
from statsmodels.tsa.regime_switching.markov_regression import MarkovRegression
from fredapi import Fred
import sqlite3
import os
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import gridspec
import matplotlib.dates as mdates
from pandas.tseries.offsets import Day
from decimal import Decimal
import requests
import seaborn as sns
color_pal = sns.color_palette()
from pandas.tseries.offsets import BDay
from multiprocessing import Pool
from tqdm import tqdm

# Parameters
ticker = '^GSPC'
start_date = '1950-01-01'
end_date = '2024-11-15'
split_date = '2024-11-15'

# Download data
data = yf.download(ticker, start=start_date, end=end_date)

# Use adjusted close price
data = data[['Adj Close']]
data.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)

# Calculate daily returns
data['Index_Returns'] = data['Adj_Close'].pct_change()
data.dropna(inplace=True)

# Separate train and test sets for 'Index_Returns'
train = data.loc[data.index < split_date, 'Index_Returns']
test = data.loc[data.index >= split_date, 'Index_Returns']

# Fit the Markov Switching Model on the Training Data
train_model = MarkovRegression(train, k_regimes=2, trend='c', switching_variance=True)
train_result = train_model.fit()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\1988895487.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\1988895487.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Index_Returns'] = data['Adj_Close'].pct_change()
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\1988895487.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
train_regimes = train_result.smoothed_marginal_probabilities.idxmax(axis=1)
data.loc[train.index, 'Training Regime'] = train_regimes
# Out:
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\1490037833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[train.index, 'Training Regime'] = train_regimes

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime
# Date
# 1950-01-04    16.850000       0.011405              0.0
# 1950-01-05    16.930000       0.004748              0.0
# 1950-01-06    16.980000       0.002953              0.0
# 1950-01-09    17.080000       0.005889              0.0
# 1950-01-10    17.030001      -0.002927              0.0
# ...                 ...            ...              ...
# 2024-11-07  5973.100098       0.007431              NaN
# 2024-11-08  5995.540039       0.003757              NaN
# 2024-11-11  6001.350098       0.000969              NaN
# 2024-11-12  5983.990234      -0.002893              NaN
# 2024-11-13  5985.379883       0.000232              NaN
#
# [18838 rows x 3 columns]

# %%
# Ensure columns are initialized before the loop
data['Recursive_Predictions'] = np.nan
data['Recursive_Predicted_Regime_Label'] = np.nan
data['T2_Recursive_Predictions'] = np.nan  # Initialize for t+2 predictions
data['T2_Recursive_Predicted_Regime_Label'] = np.nan  # Initialize labels for t+2 predictions

# Loop over the test dates, including the last date, using tqdm for progress bar
test_dates = test.index
for i, date in enumerate(tqdm(test_dates)):
    # Expand the training data to include up to the current date
    recursive_train = data.loc[data.index <= date, 'Index_Returns']

    # Fit the Markov Switching Model on the expanded training data
    recursive_model = MarkovRegression(recursive_train, k_regimes=2, trend='c', switching_variance=True)
    try:
        recursive_result = recursive_model.fit(disp=False)
    except Exception as e:
        print(f"Model failed to converge at date {date}: {e}")
        continue  # Skip this date if the model fails to fit

    # Extract smoothed probabilities and last known state probabilities
    smoothed_probs = recursive_result.smoothed_marginal_probabilities
    last_probs = smoothed_probs.iloc[-1].values

    # Extract transition probabilities from the model parameters
    params = recursive_result.params
    p_00 = params['p[0->0]']
    p_10 = params['p[1->0]']
    p_01 = 1 - p_00
    p_11 = 1 - p_10

    # Construct the transition matrix
    transition_matrix = np.array([
        [p_00, p_01],
        [p_10, p_11]
    ])

    # Update state probabilities to predict the next day's regime (t+1)
    state_probs_t1 = np.dot(last_probs, transition_matrix)

    # Determine the most likely regime at t+1
    regime_labels = smoothed_probs.columns.tolist()  # Should be [0, 1]
    most_likely_regime_t1 = regime_labels[np.argmax(state_probs_t1)]

    # Get the next date for prediction (t+1)
    if i + 1 < len(test.index):
        next_date_t1 = test.index[i + 1]
    else:
        # Predicting beyond the available data; estimate next date
        next_date_t1 = date + pd.Timedelta(days=1)
        # Add next_date_t1 to the DataFrame if it doesn't exist
        if next_date_t1 not in data.index:
            data.loc[next_date_t1] = np.nan  # Initialize with NaNs

    # Store the predicted regime in 'Recursive_Predictions' at next_date_t1
    data.at[next_date_t1, 'Recursive_Predictions'] = most_likely_regime_t1

    # Now predict the regime at t+2
    # Update state probabilities to predict the day after next's regime (t+2)
    state_probs_t2 = np.dot(state_probs_t1, transition_matrix)

    # Determine the most likely regime at t+2
    most_likely_regime_t2 = regime_labels[np.argmax(state_probs_t2)]

    # Get the date for prediction at t+2
    if i + 2 < len(test.index):
        next_date_t2 = test.index[i + 2]
    else:
        # Predicting beyond the available data; estimate next date
        next_date_t2 = date + pd.Timedelta(days=2)
        # Add next_date_t2 to the DataFrame if it doesn't exist
        if next_date_t2 not in data.index:
            data.loc[next_date_t2] = np.nan  # Initialize with NaNs

    # Store the predicted regime in 'T2_Recursive_Predictions' at next_date_t2
    data.at[next_date_t2, 'T2_Recursive_Predictions'] = most_likely_regime_t2

    # Determine which regime corresponds to low and high volatility
    variances = [params['sigma2[0]'], params['sigma2[1]']]
    sigma2_0 = variances[0]
    sigma2_1 = variances[1]

    if sigma2_0 < sigma2_1:
        regime_mapping = {0: 'Low Volatility', 1: 'High Volatility'}
    else:
        regime_mapping = {0: 'High Volatility', 1: 'Low Volatility'}

    # Map the predicted regime to labels for t+1
    predicted_label_t1 = regime_mapping[most_likely_regime_t1]
    data.at[next_date_t1, 'Recursive_Predicted_Regime_Label'] = predicted_label_t1

    # Map the predicted regime to labels for t+2
    predicted_label_t2 = regime_mapping[most_likely_regime_t2]
    data.at[next_date_t2, 'T2_Recursive_Predicted_Regime_Label'] = predicted_label_t2

# Display the recursive predictions
print(data.loc[test.index, ['Index_Returns', 'Recursive_Predictions', 'Recursive_Predicted_Regime_Label', 'T2_Recursive_Predictions', 'T2_Recursive_Predicted_Regime_Label']].head())
# Out:
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\4221826898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Recursive_Predictions'] = np.nan
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\4221826898.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Recursive_Predicted_Regime_Label'] = np.nan
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\4221826898.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['T2_Recursive_Predictions'] = np.nan  # Initialize for t+2 predictions
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\4221826898.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['T2_Recursive_Predicted_Regime_Label'] = np.nan  # Initialize labels for t+2 predictions
#   0%|          | 0/2484 [00:00<?, ?it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 1/2484 [00:04<2:53:13,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 2/2484 [00:08<2:52:53,  4.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 3/2484 [00:12<2:54:20,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 4/2484 [00:16<2:54:20,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 5/2484 [00:21<2:53:35,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 6/2484 [00:25<2:54:22,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 7/2484 [00:29<2:54:46,  4.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 8/2484 [00:33<2:55:20,  4.25s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 9/2484 [00:38<2:55:45,  4.26s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 10/2484 [00:42<2:54:30,  4.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 11/2484 [00:46<2:54:41,  4.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   0%|          | 12/2484 [00:50<2:54:31,  4.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 13/2484 [00:54<2:53:20,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 14/2484 [00:59<2:53:48,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 15/2484 [01:03<2:54:12,  4.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 16/2484 [01:07<2:54:24,  4.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 17/2484 [01:11<2:53:07,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 18/2484 [01:15<2:52:38,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 19/2484 [01:20<2:51:57,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 20/2484 [01:24<2:51:35,  4.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 21/2484 [01:28<2:51:15,  4.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 22/2484 [01:32<2:51:49,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 23/2484 [01:36<2:52:21,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 24/2484 [01:41<2:51:46,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 25/2484 [01:45<2:52:14,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 26/2484 [01:49<2:48:41,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 27/2484 [01:53<2:49:04,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 28/2484 [01:57<2:49:13,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 29/2484 [02:01<2:48:22,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 30/2484 [02:05<2:48:02,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|          | 31/2484 [02:09<2:47:03,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|▏         | 32/2484 [02:13<2:46:02,  4.06s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|▏         | 33/2484 [02:17<2:47:19,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|▏         | 34/2484 [02:21<2:45:27,  4.05s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|▏         | 35/2484 [02:25<2:45:39,  4.06s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|▏         | 36/2484 [02:29<2:44:43,  4.04s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   1%|▏         | 37/2484 [02:33<2:43:54,  4.02s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 38/2484 [02:38<2:45:48,  4.07s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 39/2484 [02:42<2:46:53,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 40/2484 [02:46<2:47:40,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 41/2484 [02:50<2:48:01,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 42/2484 [02:54<2:49:13,  4.16s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 43/2484 [02:59<2:50:03,  4.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 44/2484 [03:03<2:49:33,  4.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 45/2484 [03:07<2:49:20,  4.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 46/2484 [03:11<2:49:23,  4.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 47/2484 [03:15<2:50:49,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 48/2484 [03:20<2:50:52,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 49/2484 [03:24<2:50:42,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 50/2484 [03:28<2:50:37,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 51/2484 [03:32<2:48:56,  4.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 52/2484 [03:36<2:47:24,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 53/2484 [03:40<2:46:07,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 54/2484 [03:44<2:46:09,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 55/2484 [03:49<2:59:49,  4.44s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 56/2484 [03:54<2:55:49,  4.34s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 57/2484 [03:58<2:52:44,  4.27s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 58/2484 [04:02<2:51:04,  4.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 59/2484 [04:06<2:49:43,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 60/2484 [04:10<2:49:31,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 61/2484 [04:14<2:47:15,  4.14s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   2%|▏         | 62/2484 [04:18<2:46:46,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 63/2484 [04:22<2:45:20,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 64/2484 [04:26<2:44:20,  4.07s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 65/2484 [04:30<2:44:40,  4.08s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 66/2484 [04:34<2:44:31,  4.08s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 67/2484 [04:39<2:44:48,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 68/2484 [04:43<2:45:15,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 69/2484 [04:47<2:44:53,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 70/2484 [04:51<2:45:42,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 71/2484 [04:55<2:45:50,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 72/2484 [04:59<2:44:58,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 73/2484 [05:03<2:45:20,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 74/2484 [05:07<2:44:39,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 75/2484 [05:11<2:44:27,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 76/2484 [05:15<2:44:09,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 77/2484 [05:20<2:44:14,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 78/2484 [05:24<2:44:50,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 79/2484 [05:28<2:44:21,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 80/2484 [05:32<2:44:24,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 81/2484 [05:36<2:46:47,  4.16s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 82/2484 [05:41<2:52:09,  4.30s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 83/2484 [05:45<2:48:59,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 84/2484 [05:49<2:47:02,  4.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 85/2484 [05:53<2:48:24,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   3%|▎         | 86/2484 [05:57<2:48:29,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 87/2484 [06:02<2:50:55,  4.28s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 88/2484 [06:06<2:49:03,  4.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 89/2484 [06:10<2:50:05,  4.26s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 90/2484 [06:15<2:50:40,  4.28s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 91/2484 [06:19<2:48:17,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 92/2484 [06:23<2:47:27,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▎         | 93/2484 [06:27<2:46:53,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 94/2484 [06:31<2:46:18,  4.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 95/2484 [06:35<2:45:43,  4.16s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 96/2484 [06:39<2:44:30,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 97/2484 [06:43<2:43:38,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 98/2484 [06:48<2:44:14,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 99/2484 [06:52<2:43:34,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 100/2484 [06:56<2:44:30,  4.14s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 101/2484 [07:00<2:45:18,  4.16s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 102/2484 [07:04<2:46:16,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 103/2484 [07:09<2:47:26,  4.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 104/2484 [07:13<2:46:53,  4.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 105/2484 [07:17<2:46:37,  4.20s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 106/2484 [07:21<2:46:12,  4.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 107/2484 [07:25<2:44:21,  4.15s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 108/2484 [07:29<2:42:54,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 109/2484 [07:33<2:42:50,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 110/2484 [07:38<2:43:00,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   4%|▍         | 111/2484 [07:42<2:42:54,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 112/2484 [07:46<2:41:52,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 113/2484 [07:50<2:41:00,  4.07s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 114/2484 [07:54<2:40:46,  4.07s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 115/2484 [07:58<2:41:27,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 116/2484 [08:02<2:42:08,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 117/2484 [08:06<2:43:18,  4.14s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 118/2484 [08:10<2:43:21,  4.14s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 119/2484 [08:14<2:42:08,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 120/2484 [08:19<2:42:13,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 121/2484 [08:23<2:42:32,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 122/2484 [08:27<2:41:31,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 123/2484 [08:31<2:41:48,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▍         | 124/2484 [08:35<2:41:47,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 125/2484 [08:39<2:41:44,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 126/2484 [08:43<2:41:52,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 127/2484 [08:47<2:40:53,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 128/2484 [08:51<2:41:05,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 129/2484 [08:56<2:41:05,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 130/2484 [09:00<2:41:06,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 131/2484 [09:04<2:40:21,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 132/2484 [09:08<2:41:48,  4.13s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 133/2484 [09:12<2:40:48,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 134/2484 [09:16<2:42:12,  4.14s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 135/2484 [09:20<2:42:08,  4.14s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   5%|▌         | 136/2484 [09:24<2:41:02,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   6%|▌         | 137/2484 [09:28<2:40:05,  4.09s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   6%|▌         | 138/2484 [09:33<2:40:25,  4.10s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   6%|▌         | 139/2484 [09:37<2:40:42,  4.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   6%|▌         | 140/2484 [09:41<2:40:55,  4.12s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   6%|▌         | 141/2484 [09:45<2:42:03,  4.15s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
#   self._init_dates(dates, freq)
#  98%|█████████▊| 2442/2484 [3:08:54<03:37,  5.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  98%|█████████▊| 2443/2484 [3:08:59<03:31,  5.16s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  98%|█████████▊| 2444/2484 [3:09:04<03:26,  5.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  98%|█████████▊| 2445/2484 [3:09:09<03:21,  5.17s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  98%|█████████▊| 2446/2484 [3:09:15<03:16,  5.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▊| 2447/2484 [3:09:20<03:11,  5.18s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▊| 2448/2484 [3:09:25<03:07,  5.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▊| 2449/2484 [3:09:30<03:01,  5.19s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▊| 2450/2484 [3:09:35<02:56,  5.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▊| 2451/2484 [3:09:41<02:52,  5.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▊| 2452/2484 [3:09:46<02:47,  5.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2453/2484 [3:09:51<02:41,  5.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2454/2484 [3:09:56<02:36,  5.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2455/2484 [3:10:02<02:31,  5.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2456/2484 [3:10:07<02:26,  5.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2457/2484 [3:10:12<02:20,  5.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2458/2484 [3:10:17<02:15,  5.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2459/2484 [3:10:22<02:10,  5.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2460/2484 [3:10:28<02:05,  5.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2461/2484 [3:10:33<01:59,  5.21s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2462/2484 [3:10:38<01:54,  5.22s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2463/2484 [3:10:43<01:49,  5.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2464/2484 [3:10:49<01:44,  5.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2465/2484 [3:10:54<01:39,  5.24s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2466/2484 [3:10:59<01:34,  5.25s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2467/2484 [3:11:04<01:29,  5.25s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2468/2484 [3:11:10<01:24,  5.28s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2469/2484 [3:11:15<01:21,  5.40s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2470/2484 [3:11:21<01:15,  5.37s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  99%|█████████▉| 2471/2484 [3:11:26<01:09,  5.35s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2472/2484 [3:11:31<01:04,  5.34s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2473/2484 [3:11:36<00:57,  5.23s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2474/2484 [3:11:41<00:51,  5.16s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2475/2484 [3:11:46<00:45,  5.11s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2476/2484 [3:11:51<00:40,  5.07s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2477/2484 [3:11:56<00:35,  5.04s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2478/2484 [3:12:01<00:30,  5.03s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2479/2484 [3:12:06<00:24,  4.98s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2480/2484 [3:12:11<00:19,  4.99s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2481/2484 [3:12:16<00:14,  4.98s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# 100%|█████████▉| 2482/2484 [3:12:21<00:09,  4.98s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\4221826898.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[next_date_t2] = np.nan  # Initialize with NaNs
# 100%|█████████▉| 2483/2484 [3:12:26<00:04,  4.98s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\4221826898.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[next_date_t2] = np.nan  # Initialize with NaNs
# 100%|██████████| 2484/2484 [3:12:31<00:00,  4.65s/it]
#             Index_Returns  Recursive_Predictions  \
# Date
# 2015-01-02      -0.000340                    NaN
# 2015-01-05      -0.018278                    0.0
# 2015-01-06      -0.008893                    0.0
# 2015-01-07       0.011630                    0.0
# 2015-01-08       0.017888                    0.0
#
#            Recursive_Predicted_Regime_Label  T2_Recursive_Predictions  \
# Date
# 2015-01-02                              NaN                       NaN
# 2015-01-05                   Low Volatility                       NaN
# 2015-01-06                   Low Volatility                       0.0
# 2015-01-07                   Low Volatility                       0.0
# 2015-01-08                   Low Volatility                       0.0
#
#            T2_Recursive_Predicted_Regime_Label
# Date
# 2015-01-02                                 NaN
# 2015-01-05                                 NaN
# 2015-01-06                      Low Volatility
# 2015-01-07                      Low Volatility
# 2015-01-08                      Low Volatility

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime  \
# Date
# 1950-01-04    16.850000       0.011405              0.0
# 1950-01-05    16.930000       0.004748              0.0
# 1950-01-06    16.980000       0.002953              0.0
# 1950-01-09    17.080000       0.005889              0.0
# 1950-01-10    17.030001      -0.002927              0.0
# ...                 ...            ...              ...
# 2024-11-11  6001.350098       0.000969              NaN
# 2024-11-12  5983.990234      -0.002893              NaN
# 2024-11-13  5985.379883       0.000232              NaN
# 2024-11-14          NaN            NaN              NaN
# 2024-11-15          NaN            NaN              NaN
#
#             Recursive_Predictions Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-04                    NaN                              NaN
# 1950-01-05                    NaN                              NaN
# 1950-01-06                    NaN                              NaN
# 1950-01-09                    NaN                              NaN
# 1950-01-10                    NaN                              NaN
# ...                           ...                              ...
# 2024-11-11                    1.0                  High Volatility
# 2024-11-12                    0.0                   Low Volatility
# 2024-11-13                    0.0                   Low Volatility
# 2024-11-14                    0.0                   Low Volatility
# 2024-11-15                    NaN                              NaN
#
#             T2_Recursive_Predictions T2_Recursive_Predicted_Regime_Label
# Date
# 1950-01-04                       NaN                                 NaN
# 1950-01-05                       NaN                                 NaN
# 1950-01-06                       NaN                                 NaN
# 1950-01-09                       NaN                                 NaN
# 1950-01-10                       NaN                                 NaN
# ...                              ...                                 ...
# 2024-11-11                       1.0                     High Volatility
# 2024-11-12                       1.0                     High Volatility
# 2024-11-13                       0.0                      Low Volatility
# 2024-11-14                       0.0                      Low Volatility
# 2024-11-15                       0.0                      Low Volatility
#
# [18840 rows x 7 columns]

# %%
# Check for NaNs in 'Index_Returns' and drop them
returns = data['Index_Returns'].dropna()

# Fit Markov Switching Model
model = MarkovRegression(returns, k_regimes=2, trend='c', switching_variance=True)
result = model.fit()
print(result.summary())

# Add regime to the data
data.loc[returns.index, 'Full_Vol_Regime'] = result.smoothed_marginal_probabilities.idxmax(axis=1)
# Out:
# C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          Index_Returns   No. Observations:                18838
# Model:               MarkovRegression   Log Likelihood               63437.163
# Date:                Thu, 14 Nov 2024   AIC                        -126862.326
# Time:                        16:01:39   BIC                        -126815.264
# Sample:                             0   HQIC                       -126846.884
#                               - 18838
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007   5.65e-05     11.530      0.000       0.001       0.001
# sigma2      3.997e-05   8.07e-07     49.547      0.000    3.84e-05    4.16e-05
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.000     -2.126      0.033      -0.001   -4.24e-05
# sigma2         0.0003   8.36e-06     33.295      0.000       0.000       0.000
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9880      0.001    723.561      0.000       0.985       0.991
# p[1->0]        0.0374      0.004      9.103      0.000       0.029       0.045
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\2357773592.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[returns.index, 'Full_Vol_Regime'] = result.smoothed_marginal_probabilities.idxmax(axis=1)

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime  \
# Date
# 1950-01-04    16.850000       0.011405              0.0
# 1950-01-05    16.930000       0.004748              0.0
# 1950-01-06    16.980000       0.002953              0.0
# 1950-01-09    17.080000       0.005889              0.0
# 1950-01-10    17.030001      -0.002927              0.0
# ...                 ...            ...              ...
# 2024-11-11  6001.350098       0.000969              NaN
# 2024-11-12  5983.990234      -0.002893              NaN
# 2024-11-13  5985.379883       0.000232              NaN
# 2024-11-14          NaN            NaN              NaN
# 2024-11-15          NaN            NaN              NaN
#
#             Recursive_Predictions Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-04                    NaN                              NaN
# 1950-01-05                    NaN                              NaN
# 1950-01-06                    NaN                              NaN
# 1950-01-09                    NaN                              NaN
# 1950-01-10                    NaN                              NaN
# ...                           ...                              ...
# 2024-11-11                    1.0                  High Volatility
# 2024-11-12                    0.0                   Low Volatility
# 2024-11-13                    0.0                   Low Volatility
# 2024-11-14                    0.0                   Low Volatility
# 2024-11-15                    NaN                              NaN
#
#             T2_Recursive_Predictions T2_Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-04                       NaN                                 NaN
# 1950-01-05                       NaN                                 NaN
# 1950-01-06                       NaN                                 NaN
# 1950-01-09                       NaN                                 NaN
# 1950-01-10                       NaN                                 NaN
# ...                              ...                                 ...
# 2024-11-11                       1.0                     High Volatility
# 2024-11-12                       1.0                     High Volatility
# 2024-11-13                       0.0                      Low Volatility
# 2024-11-14                       0.0                      Low Volatility
# 2024-11-15                       0.0                      Low Volatility
#
#             Full_Vol_Regime
# Date
# 1950-01-04              0.0
# 1950-01-05              0.0
# 1950-01-06              0.0
# 1950-01-09              0.0
# 1950-01-10              0.0
# ...                     ...
# 2024-11-11              0.0
# 2024-11-12              0.0
# 2024-11-13              0.0
# 2024-11-14              NaN
# 2024-11-15              NaN
#
# [18840 rows x 8 columns]

# %%
# Non-Recursive Non-Updating Parameter Set

# Extract the smoothed probabilities for the training data
smoothed_probs = train_result.smoothed_marginal_probabilities

# Extract the last known state probabilities (at the end of the training data)
last_probs = smoothed_probs.iloc[-1].values  # Convert to NumPy array

# Regime labels (from smoothed probabilities)
regime_labels = smoothed_probs.columns.tolist()  # Should be [0, 1]

# Extract transition probabilities from the model parameters
params = train_result.params

# Transition probabilities
p_00 = params['p[0->0]']  # Probability of staying in Regime 0
p_10 = params['p[1->0]']  # Probability of moving from Regime 1 to Regime 0

# Probabilities of transitioning to Regime 1
p_01 = 1 - p_00           # Probability of moving from Regime 0 to Regime 1
p_11 = 1 - p_10           # Probability of staying in Regime 1

# Construct the transition matrix
transition_matrix = np.array([
    [p_00, p_01],  # Transitions from Regime 0
    [p_10, p_11]   # Transitions from Regime 1
])

# Regime-specific variances
variances = [params['sigma2[0]'], params['sigma2[1]']]

# Initialize columns for state probabilities and predicted regime in the data DataFrame
data['State_Prob_Regime0'] = np.nan
data['State_Prob_Regime1'] = np.nan
data['Predicted_Regime'] = np.nan

# Initialize state probabilities with the last known probabilities from the training data
state_probs = last_probs.copy()

# Loop over each date in the test set within the data DataFrame
for date in test.index:
    # Update state probabilities using the transition matrix
    state_probs = np.dot(state_probs, transition_matrix)
    
    # Store the state probabilities in the DataFrame
    data.at[date, 'State_Prob_Regime0'] = state_probs[0]
    data.at[date, 'State_Prob_Regime1'] = state_probs[1]
    
    # Determine the most likely regime
    most_likely_regime = regime_labels[np.argmax(state_probs)]
    
    # Store the predicted regime in the DataFrame
    data.at[date, 'Predicted_Regime'] = most_likely_regime

# Determine which regime corresponds to low volatility and high volatility
sigma2_0 = variances[0]
sigma2_1 = variances[1]

if sigma2_0 < sigma2_1:
    regime_mapping = {0: 'Low Volatility', 1: 'High Volatility'}
else:
    regime_mapping = {0: 'High Volatility', 1: 'Low Volatility'}

# Map the predicted regimes to labels
data['Predicted_Regime_Label'] = data['Predicted_Regime'].map(regime_mapping)

# # Display the first few rows of the data DataFrame for the test period
# print(data.loc[test.index, ['Index_Returns', 'State_Prob_Regime0', 'State_Prob_Regime1', 'Predicted_Regime', 'Predicted_Regime_Label']].head())
# Create the 'Blended_Test_Training_Regime' by merging 'Training Regime' and 'Predicted_Regime' based on date condition
data['Blended_Test_Training_Regime'] = None  # Initialize the column with None

# Set values from 'Training Regime' for dates before split_date
data.loc[data.index < split_date, 'Blended_Test_Training_Regime'] = data['Training Regime']

# Set values from 'Predicted_Regime' for dates on or after split_date
data.loc[data.index >= split_date, 'Blended_Test_Training_Regime'] = data['Predicted_Regime']

# Display the DataFrame with the new 'Blended_Test_Training_Regime' column
print(data[['Training Regime', 'Predicted_Regime', 'Blended_Test_Training_Regime']])
# Out:
#             Training Regime  Predicted_Regime Blended_Test_Training_Regime
# Date
# 1950-01-04              0.0               NaN                          0.0
# 1950-01-05              0.0               NaN                          0.0
# 1950-01-06              0.0               NaN                          0.0
# 1950-01-09              0.0               NaN                          0.0
# 1950-01-10              0.0               NaN                          0.0
# ...                     ...               ...                          ...
# 2024-11-11              NaN               0.0                          0.0
# 2024-11-12              NaN               0.0                          0.0
# 2024-11-13              NaN               0.0                          0.0
# 2024-11-14              NaN               NaN                          NaN
# 2024-11-15              NaN               NaN                          NaN
#
# [18840 rows x 3 columns]
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\3817632276.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['State_Prob_Regime0'] = np.nan
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\3817632276.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['State_Prob_Regime1'] = np.nan
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\3817632276.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Predicted_Regime'] = np.nan
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\3817632276.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Predicted_Regime_Label'] = data['Predicted_Regime'].map(regime_mapping)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_10036\3817632276.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Blended_Test_Training_Regime'] = None  # Initialize the column with None

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime  \
# Date
# 1950-01-04    16.850000       0.011405              0.0
# 1950-01-05    16.930000       0.004748              0.0
# 1950-01-06    16.980000       0.002953              0.0
# 1950-01-09    17.080000       0.005889              0.0
# 1950-01-10    17.030001      -0.002927              0.0
# ...                 ...            ...              ...
# 2024-11-11  6001.350098       0.000969              NaN
# 2024-11-12  5983.990234      -0.002893              NaN
# 2024-11-13  5985.379883       0.000232              NaN
# 2024-11-14          NaN            NaN              NaN
# 2024-11-15          NaN            NaN              NaN
#
#             Recursive_Predictions Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-04                    NaN                              NaN
# 1950-01-05                    NaN                              NaN
# 1950-01-06                    NaN                              NaN
# 1950-01-09                    NaN                              NaN
# 1950-01-10                    NaN                              NaN
# ...                           ...                              ...
# 2024-11-11                    1.0                  High Volatility
# 2024-11-12                    0.0                   Low Volatility
# 2024-11-13                    0.0                   Low Volatility
# 2024-11-14                    0.0                   Low Volatility
# 2024-11-15                    NaN                              NaN
#
#             T2_Recursive_Predictions T2_Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-04                       NaN                                 NaN
# 1950-01-05                       NaN                                 NaN
# 1950-01-06                       NaN                                 NaN
# 1950-01-09                       NaN                                 NaN
# 1950-01-10                       NaN                                 NaN
# ...                              ...                                 ...
# 2024-11-11                       1.0                     High Volatility
# 2024-11-12                       1.0                     High Volatility
# 2024-11-13                       0.0                      Low Volatility
# 2024-11-14                       0.0                      Low Volatility
# 2024-11-15                       0.0                      Low Volatility
#
#             Full_Vol_Regime  State_Prob_Regime0  State_Prob_Regime1  \
# Date
# 1950-01-04              0.0                 NaN                 NaN
# 1950-01-05              0.0                 NaN                 NaN
# 1950-01-06              0.0                 NaN                 NaN
# 1950-01-09              0.0                 NaN                 NaN
# 1950-01-10              0.0                 NaN                 NaN
# ...                     ...                 ...                 ...
# 2024-11-11              0.0            0.763607            0.236393
# 2024-11-12              0.0            0.763607            0.236393
# 2024-11-13              0.0            0.763607            0.236393
# 2024-11-14              NaN                 NaN                 NaN
# 2024-11-15              NaN                 NaN                 NaN
#
#             Predicted_Regime Predicted_Regime_Label  \
# Date
# 1950-01-04               NaN                    NaN
# 1950-01-05               NaN                    NaN
# 1950-01-06               NaN                    NaN
# 1950-01-09               NaN                    NaN
# 1950-01-10               NaN                    NaN
# ...                      ...                    ...
# 2024-11-11               0.0         Low Volatility
# 2024-11-12               0.0         Low Volatility
# 2024-11-13               0.0         Low Volatility
# 2024-11-14               NaN                    NaN
# 2024-11-15               NaN                    NaN
#
#            Blended_Test_Training_Regime
# Date
# 1950-01-04                          0.0
# 1950-01-05                          0.0
# 1950-01-06                          0.0
# 1950-01-09                          0.0
# 1950-01-10                          0.0
# ...                                 ...
# 2024-11-11                          0.0
# 2024-11-12                          0.0
# 2024-11-13                          0.0
# 2024-11-14                          NaN
# 2024-11-15                          NaN
#
# [18840 rows x 13 columns]

# %%
# Flatten MultiIndex columns if necessary
if isinstance(data.columns, pd.MultiIndex):
    data.columns = ['_'.join(filter(None, col)) for col in data.columns]

# Specify the database filename
db_filename = 'v3output/fill_forward_comparison.db'

# Connect to the SQLite database
conn = sqlite3.connect(db_filename)

# Table name for main data export
table_name = 'regime_data'

# Write the flattened DataFrame to the SQLite database
data.to_sql(table_name, conn, if_exists='replace', index=True)

# Verify the table structure after export
cursor = conn.cursor()
cursor.execute(f"PRAGMA table_info({table_name})")
schema = cursor.fetchall()
print("Table schema:", schema)

# Close the connection
conn.close()
# Out:
# Table schema: [(0, 'Date', 'TIMESTAMP', 0, None, 0), (1, 'Adj_Close', 'REAL', 0, None, 0), (2, 'Index_Returns', 'REAL', 0, None, 0), (3, 'Training Regime', 'REAL', 0, None, 0), (4, 'Recursive_Predictions', 'REAL', 0, None, 0), (5, 'Recursive_Predicted_Regime_Label', 'TEXT', 0, None, 0), (6, 'T2_Recursive_Predictions', 'REAL', 0, None, 0), (7, 'T2_Recursive_Predicted_Regime_Label', 'TEXT', 0, None, 0), (8, 'Full_Vol_Regime', 'REAL', 0, None, 0), (9, 'State_Prob_Regime0', 'REAL', 0, None, 0), (10, 'State_Prob_Regime1', 'REAL', 0, None, 0), (11, 'Predicted_Regime', 'REAL', 0, None, 0), (12, 'Predicted_Regime_Label', 'TEXT', 0, None, 0), (13, 'Blended_Test_Training_Regime', 'REAL', 0, None, 0)]

# %%
# Filter for rows where 'Recursive_Predictions' and 'Full_Vol_Regime' do not match, excluding NaNs
filtered_data = data[(data['Recursive_Predictions'] != data['Full_Vol_Regime'])].dropna(subset=['Recursive_Predictions', 'Full_Vol_Regime'])

# Flatten MultiIndex columns if necessary
if isinstance(filtered_data.columns, pd.MultiIndex):
    filtered_data.columns = ['_'.join(filter(None, col)) for col in filtered_data.columns]

# Connect to the SQLite database
conn = sqlite3.connect(db_filename)

# Table name for filtered data
new_table_name = 'mismatched_regimes'

# Write the filtered DataFrame to the SQLite database
filtered_data.to_sql(new_table_name, conn, if_exists='replace', index=True)

# Verify the table structure for the filtered data
cursor = conn.cursor()
cursor.execute(f"PRAGMA table_info({new_table_name})")
filtered_schema = cursor.fetchall()
print("Filtered Table schema:", filtered_schema)

# Close the connection
conn.close()
# Out:
# Filtered Table schema: [(0, 'Date', 'TIMESTAMP', 0, None, 0), (1, 'Adj_Close', 'REAL', 0, None, 0), (2, 'Index_Returns', 'REAL', 0, None, 0), (3, 'Training Regime', 'REAL', 0, None, 0), (4, 'Recursive_Predictions', 'REAL', 0, None, 0), (5, 'Recursive_Predicted_Regime_Label', 'TEXT', 0, None, 0), (6, 'T2_Recursive_Predictions', 'REAL', 0, None, 0), (7, 'T2_Recursive_Predicted_Regime_Label', 'TEXT', 0, None, 0), (8, 'Full_Vol_Regime', 'REAL', 0, None, 0), (9, 'State_Prob_Regime0', 'REAL', 0, None, 0), (10, 'State_Prob_Regime1', 'REAL', 0, None, 0), (11, 'Predicted_Regime', 'REAL', 0, None, 0), (12, 'Predicted_Regime_Label', 'TEXT', 0, None, 0), (13, 'Blended_Test_Training_Regime', 'REAL', 0, None, 0)]

# %%
# Connect to the SQLite database
conn = sqlite3.connect(db_filename)

# Retrieve the main data table
query = "SELECT * FROM regime_data"
df_main = pd.read_sql_query(query, conn)

# Export the main data to CSV
output_csv_path_main = 'v3output/regime_data_export.csv'
df_main.to_csv(output_csv_path_main, index=False)
print(f"Main data exported to {output_csv_path_main}")

# Retrieve the filtered data table
query_filtered = "SELECT * FROM mismatched_regimes"
df_filtered = pd.read_sql_query(query_filtered, conn)

# Export the filtered data to CSV
output_csv_path_filtered = 'v3output/mismatched_regimes_export.csv'
df_filtered.to_csv(output_csv_path_filtered, index=False)
print(f"Filtered data exported to {output_csv_path_filtered}")

# Close the connection
conn.close()
# Out:
# Main data exported to v3output/regime_data_export.csv
# Filtered data exported to v3output/mismatched_regimes_export.csv

# %%
# Function to send Telegram message
def telegram_messenger():
    # Telegram Bot API token and Channel ID
    bot_token = '7328648943:AAH3gHyGf2xgjxBfzPd05F_7IagASgs-Dj0'
    channel_id = '-1002309744206'

    # Connect to the database
    conn = sqlite3.connect('v3output/fill_forward_comparison.db')

    # Query the last two rows from 'Market_Regime' and 'Date' columns
    query = """
    SELECT Date, Market_Regime, Portfolio_Exposure
    FROM financial_data
    ORDER BY DATE(Date) DESC
    LIMIT 2
    """

    # Execute query and load into a DataFrame
    data = pd.read_sql_query(query, conn)

    # Close the database connection
    conn.close()

    # Convert 'Date' to datetime
    data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

    # Sort data by Date in ascending order
    data = data.sort_values('Date').reset_index(drop=True)

    # Debugging: Print the data used for the Telegram message
    print("Data used for Telegram message:")
    print(data)

    # Initialize the message variable each time the code runs with bold header
    message = "<b>Your Daily Portfolio Exposure Update</b>\n\n"  # Reset message here
    labels = ["Today's Market Regime", "Tomorrow's Market Regime"]

    # Loop through the DataFrame and format the message
    for index, row in data.iterrows():
        # Format Date
        formatted_date = row['Date'].strftime('%m/%d/%Y').lstrip("0").replace("/0", "/")

        # Add the labeled message for each row with line breaks for better formatting
        message += f"<u>{labels[index]}</u>\n"
        message += f"<i>Date</i>: {formatted_date}\n"
        message += f"<i>Market Regime</i>: {row['Market_Regime']}\n"
        message += f"<i>Portfolio Exposure</i>: {row['Portfolio_Exposure'] * 100:.0f}%\n"

    # Telegram API URL
    api_url = f'https://api.telegram.org/bot{bot_token}/sendMessage'

    # Payload to send with HTML formatting enabled
    payload = {
        'chat_id': channel_id,
        'text': message,
        'parse_mode': 'HTML'  # Enables HTML for bold formatting
    }

    # Send the request
    response = requests.post(api_url, json=payload)

    # Check the response
    if response.status_code == 200:
        print('Message sent successfully!')
    else:
        print(f'Failed to send message. Error: {response.text}')
