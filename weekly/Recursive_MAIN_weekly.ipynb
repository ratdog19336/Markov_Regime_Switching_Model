# %%
import numpy as np
import pandas as pd
import yfinance as yf
from statsmodels.tsa.regime_switching.markov_regression import MarkovRegression
from fredapi import Fred
import sqlite3
import os
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import gridspec
import matplotlib.dates as mdates
from pandas.tseries.offsets import Day
from decimal import Decimal
import requests
import seaborn as sns
color_pal = sns.color_palette()
from pandas.tseries.offsets import BDay
from multiprocessing import Pool
from tqdm import tqdm


# Parameters
ticker = "^GSPC"
start_date = "1950-01-01"
end_date = "2024-11-15"
split_date = '2015-01-01'

# Download data
data = yf.download(ticker, start=start_date, end=end_date, interval="1wk")

# Use adjusted close price
data = data[['Adj Close']]
data.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)

# Calculate daily returns
data['Index_Returns'] = data['Adj_Close'].pct_change()
data.dropna(inplace=True)

# Separate train and test sets for 'Index_Returns'
train = data.loc[data.index < split_date, 'Index_Returns']
test = data.loc[data.index >= split_date, 'Index_Returns']

# Fit the Markov Switching Model on the Training Data
train_model = MarkovRegression(train, k_regimes=2, trend='c', switching_variance=True)
train_result = train_model.fit()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\3142888255.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\3142888255.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Index_Returns'] = data['Adj_Close'].pct_change()
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\3142888255.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)

# %%
train_regimes = train_result.smoothed_marginal_probabilities.idxmax(axis=1)
data.loc[train.index, 'Training Regime'] = train_regimes
# Out:
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\1490037833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[train.index, 'Training Regime'] = train_regimes

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime
# Date
# 1950-01-08    16.650000      -0.025746              0.0
# 1950-01-15    16.940001       0.017417              0.0
# 1950-01-22    16.900000      -0.002361              0.0
# 1950-01-29    17.350000       0.026627              0.0
# 1950-02-05    17.209999      -0.008069              0.0
# ...                 ...            ...              ...
# 2024-10-20  5808.120117      -0.009642              NaN
# 2024-10-27  5728.799805      -0.013657              NaN
# 2024-11-03  5995.540039       0.046561              NaN
# 2024-11-10  5985.379883      -0.001695              NaN
# 2024-11-13  5985.379883       0.000000              NaN
#
# [3907 rows x 3 columns]

# %%
# Loop over the test dates, including the last date
test_dates = test.index
for i, date in enumerate(tqdm(test_dates, desc='Processing dates')):
    # Expand the training data to include up to the current date
    recursive_train = data.loc[data.index <= date, 'Index_Returns']

    # Fit the Markov Switching Model on the expanded training data
    recursive_model = MarkovRegression(recursive_train, k_regimes=2, trend='c', switching_variance=True)
    try:
        recursive_result = recursive_model.fit(disp=False)
    except Exception as e:
        print(f"Model failed to converge at date {date}: {e}")
        continue  # Skip this date if the model fails to fit

    # Extract smoothed probabilities and last known state probabilities
    smoothed_probs = recursive_result.smoothed_marginal_probabilities
    last_probs = smoothed_probs.iloc[-1].values

    # Extract transition probabilities from the model parameters
    params = recursive_result.params
    p_00 = params['p[0->0]']
    p_10 = params['p[1->0]']
    p_01 = 1 - p_00
    p_11 = 1 - p_10

    # Construct the transition matrix
    transition_matrix = np.array([
        [p_00, p_01],
        [p_10, p_11]
    ])

    # Update state probabilities to predict the next day's regime
    state_probs = np.dot(last_probs, transition_matrix)

    # Determine the most likely regime at t+1
    regime_labels = smoothed_probs.columns.tolist()  # Should be [0, 1]
    most_likely_regime = regime_labels[np.argmax(state_probs)]

    # Get the next date for prediction
    if i + 1 < len(test.index):
        next_date = test.index[i + 1]
    else:
        # Predicting beyond the available data; estimate next date
        next_date = date + pd.Timedelta(days=1)
        # Add next_date to the DataFrame if it doesn't exist
        if next_date not in data.index:
            data.loc[next_date] = np.nan  # Initialize with NaNs

    # Store the predicted regime in 'Recursive_Predictions' at next_date
    data.at[next_date, 'Recursive_Predictions'] = most_likely_regime

    # Determine which regime corresponds to low and high volatility
    variances = [params['sigma2[0]'], params['sigma2[1]']]
    sigma2_0 = variances[0]
    sigma2_1 = variances[1]

    if sigma2_0 < sigma2_1:
        regime_mapping = {0: 'Low Volatility', 1: 'High Volatility'}
    else:
        regime_mapping = {0: 'High Volatility', 1: 'Low Volatility'}

    # Map the predicted regime to labels
    predicted_label = regime_mapping[most_likely_regime]
    data.at[next_date, 'Recursive_Predicted_Regime_Label'] = predicted_label

# Display the recursive predictions
print(data.loc[test.index, ['Index_Returns', 'Recursive_Predictions', 'Recursive_Predicted_Regime_Label']].head())
# Out:
# Processing dates:   0%|          | 0/516 [00:00<?, ?it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\1150266332.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.at[next_date, 'Recursive_Predictions'] = most_likely_regime
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\1150266332.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.at[next_date, 'Recursive_Predicted_Regime_Label'] = predicted_label
# Processing dates:   0%|          | 1/516 [00:00<07:07,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   0%|          | 2/516 [00:01<07:10,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   1%|          | 3/516 [00:02<07:06,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   1%|          | 4/516 [00:03<07:03,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   1%|          | 5/516 [00:04<06:58,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   1%|          | 6/516 [00:04<07:01,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   1%|▏         | 7/516 [00:05<06:58,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   2%|▏         | 8/516 [00:06<06:57,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   2%|▏         | 9/516 [00:07<06:55,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   2%|▏         | 10/516 [00:08<06:55,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   2%|▏         | 11/516 [00:09<06:56,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   2%|▏         | 12/516 [00:09<06:59,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   3%|▎         | 13/516 [00:10<06:59,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   3%|▎         | 14/516 [00:11<07:03,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   3%|▎         | 15/516 [00:12<07:02,  1.18it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   3%|▎         | 16/516 [00:13<06:55,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   3%|▎         | 17/516 [00:14<06:53,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   3%|▎         | 18/516 [00:14<06:49,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   4%|▎         | 19/516 [00:15<06:48,  1.22it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   4%|▍         | 20/516 [00:16<06:50,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   4%|▍         | 21/516 [00:17<06:49,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   4%|▍         | 22/516 [00:18<06:47,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   4%|▍         | 23/516 [00:19<06:46,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   5%|▍         | 24/516 [00:19<06:47,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   5%|▍         | 25/516 [00:20<06:47,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   5%|▌         | 26/516 [00:21<06:48,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   5%|▌         | 27/516 [00:22<06:46,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   5%|▌         | 28/516 [00:23<06:44,  1.21it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   6%|▌         | 29/516 [00:24<06:44,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   6%|▌         | 30/516 [00:24<06:43,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   6%|▌         | 31/516 [00:25<06:44,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   6%|▌         | 32/516 [00:26<06:46,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   6%|▋         | 33/516 [00:27<06:47,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   7%|▋         | 34/516 [00:28<06:48,  1.18it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   7%|▋         | 35/516 [00:29<06:46,  1.18it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   7%|▋         | 36/516 [00:29<06:41,  1.20it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   7%|▋         | 37/516 [00:30<06:43,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   7%|▋         | 38/516 [00:31<06:41,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   8%|▊         | 39/516 [00:32<06:41,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   8%|▊         | 40/516 [00:33<06:40,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   8%|▊         | 41/516 [00:34<06:39,  1.19it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   8%|▊         | 42/516 [00:34<06:41,  1.18it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   8%|▊         | 43/516 [00:35<06:41,  1.18it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   9%|▊         | 44/516 [00:36<06:43,  1.17it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   9%|▊         | 45/516 [00:37<06:43,  1.17it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   9%|▉         | 46/516 [00:38<06:46,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   9%|▉         | 47/516 [00:39<06:45,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   9%|▉         | 48/516 [00:40<06:44,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:   9%|▉         | 49/516 [00:41<06:44,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  10%|▉         | 50/516 [00:41<06:44,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  10%|▉         | 51/516 [00:42<06:43,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  10%|█         | 52/516 [00:43<06:41,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  10%|█         | 53/516 [00:44<06:43,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  10%|█         | 54/516 [00:45<06:43,  1.14it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  11%|█         | 55/516 [00:46<06:42,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  11%|█         | 56/516 [00:47<06:39,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  11%|█         | 57/516 [00:48<06:36,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  11%|█         | 58/516 [00:48<06:40,  1.14it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  11%|█▏        | 59/516 [00:49<06:42,  1.14it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  12%|█▏        | 60/516 [00:50<06:41,  1.14it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  12%|█▏        | 61/516 [00:51<06:43,  1.13it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  12%|█▏        | 62/516 [00:52<06:45,  1.12it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  12%|█▏        | 63/516 [00:53<06:46,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  12%|█▏        | 64/516 [00:54<06:47,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  13%|█▎        | 65/516 [00:55<06:46,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  13%|█▎        | 66/516 [00:56<06:44,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  13%|█▎        | 67/516 [00:57<06:46,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  13%|█▎        | 68/516 [00:57<06:46,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  13%|█▎        | 69/516 [00:58<06:45,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  14%|█▎        | 70/516 [00:59<06:46,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  14%|█▍        | 71/516 [01:00<06:46,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  14%|█▍        | 72/516 [01:01<06:45,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  14%|█▍        | 73/516 [01:02<06:50,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  14%|█▍        | 74/516 [01:03<06:51,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  15%|█▍        | 75/516 [01:04<06:51,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  15%|█▍        | 76/516 [01:05<06:54,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  15%|█▍        | 77/516 [01:06<06:52,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  15%|█▌        | 78/516 [01:07<06:49,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  15%|█▌        | 79/516 [01:08<06:46,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  16%|█▌        | 80/516 [01:09<06:45,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  16%|█▌        | 81/516 [01:10<06:46,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  16%|█▌        | 82/516 [01:10<06:45,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  16%|█▌        | 83/516 [01:11<06:49,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  16%|█▋        | 84/516 [01:12<06:51,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  16%|█▋        | 85/516 [01:13<06:52,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  17%|█▋        | 86/516 [01:14<06:46,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  17%|█▋        | 87/516 [01:15<06:43,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  17%|█▋        | 88/516 [01:16<06:40,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  17%|█▋        | 89/516 [01:17<06:40,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  17%|█▋        | 90/516 [01:18<06:39,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  18%|█▊        | 91/516 [01:19<06:34,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  18%|█▊        | 92/516 [01:20<06:25,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  18%|█▊        | 93/516 [01:21<06:18,  1.12it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  18%|█▊        | 94/516 [01:22<06:14,  1.13it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  18%|█▊        | 95/516 [01:22<06:10,  1.14it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  19%|█▊        | 96/516 [01:23<06:04,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  19%|█▉        | 97/516 [01:24<06:01,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  19%|█▉        | 98/516 [01:25<06:00,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  19%|█▉        | 99/516 [01:26<05:59,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  19%|█▉        | 100/516 [01:27<06:00,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  20%|█▉        | 101/516 [01:28<05:57,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  20%|█▉        | 102/516 [01:28<05:56,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  20%|█▉        | 103/516 [01:29<05:56,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  20%|██        | 104/516 [01:30<05:55,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  20%|██        | 105/516 [01:31<05:54,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  21%|██        | 106/516 [01:32<05:53,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  21%|██        | 107/516 [01:33<05:53,  1.16it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  21%|██        | 108/516 [01:34<05:54,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  21%|██        | 109/516 [01:34<05:55,  1.15it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  21%|██▏       | 110/516 [01:35<05:56,  1.14it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  22%|██▏       | 111/516 [01:36<05:59,  1.13it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  22%|██▏       | 112/516 [01:37<06:03,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  22%|██▏       | 113/516 [01:38<06:04,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  22%|██▏       | 114/516 [01:39<06:05,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  22%|██▏       | 115/516 [01:40<06:06,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  22%|██▏       | 116/516 [01:41<06:01,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  23%|██▎       | 117/516 [01:42<05:59,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  23%|██▎       | 118/516 [01:43<05:59,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  23%|██▎       | 119/516 [01:44<05:57,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  23%|██▎       | 120/516 [01:44<05:55,  1.11it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  23%|██▎       | 121/516 [01:45<06:00,  1.10it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  24%|██▎       | 122/516 [01:46<06:03,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  24%|██▍       | 123/516 [01:47<06:04,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  24%|██▍       | 124/516 [01:48<06:03,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  24%|██▍       | 125/516 [01:49<06:03,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  24%|██▍       | 126/516 [01:50<06:03,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  25%|██▍       | 127/516 [01:51<06:03,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  25%|██▍       | 128/516 [01:52<06:03,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  25%|██▌       | 129/516 [01:53<06:02,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  25%|██▌       | 130/516 [01:54<06:01,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  25%|██▌       | 131/516 [01:55<05:59,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  26%|██▌       | 132/516 [01:56<05:56,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  26%|██▌       | 133/516 [01:57<05:55,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  26%|██▌       | 134/516 [01:58<05:55,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  26%|██▌       | 135/516 [01:58<05:54,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  26%|██▋       | 136/516 [01:59<05:51,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  27%|██▋       | 137/516 [02:00<05:49,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  27%|██▋       | 138/516 [02:01<05:47,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  27%|██▋       | 139/516 [02:02<05:47,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  27%|██▋       | 140/516 [02:03<05:46,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  27%|██▋       | 141/516 [02:04<05:45,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  28%|██▊       | 142/516 [02:05<05:46,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  28%|██▊       | 143/516 [02:06<05:45,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  28%|██▊       | 144/516 [02:07<05:43,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  28%|██▊       | 145/516 [02:08<05:43,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  28%|██▊       | 146/516 [02:09<05:42,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  28%|██▊       | 147/516 [02:10<05:41,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  29%|██▊       | 148/516 [02:10<05:38,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  29%|██▉       | 149/516 [02:11<05:36,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  29%|██▉       | 150/516 [02:12<05:35,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  29%|██▉       | 151/516 [02:13<05:37,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  29%|██▉       | 152/516 [02:14<05:34,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  30%|██▉       | 153/516 [02:15<05:31,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  30%|██▉       | 154/516 [02:16<05:32,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  30%|███       | 155/516 [02:17<05:32,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  30%|███       | 156/516 [02:18<05:33,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  30%|███       | 157/516 [02:19<05:31,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  31%|███       | 158/516 [02:20<05:31,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# ...
#   self._init_dates(dates, freq)
# Processing dates:  91%|█████████ | 467/516 [07:11<00:49,  1.01s/it]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  91%|█████████ | 468/516 [07:12<00:46,  1.02it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  91%|█████████ | 469/516 [07:13<00:45,  1.04it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  91%|█████████ | 470/516 [07:14<00:44,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  91%|█████████▏| 471/516 [07:15<00:43,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  91%|█████████▏| 472/516 [07:16<00:41,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  92%|█████████▏| 473/516 [07:17<00:40,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  92%|█████████▏| 474/516 [07:18<00:39,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  92%|█████████▏| 475/516 [07:19<00:38,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  92%|█████████▏| 476/516 [07:20<00:37,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  92%|█████████▏| 477/516 [07:21<00:36,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  93%|█████████▎| 478/516 [07:21<00:35,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  93%|█████████▎| 479/516 [07:22<00:34,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  93%|█████████▎| 480/516 [07:23<00:33,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  93%|█████████▎| 481/516 [07:24<00:32,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  93%|█████████▎| 482/516 [07:25<00:31,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  94%|█████████▎| 483/516 [07:26<00:31,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  94%|█████████▍| 484/516 [07:27<00:29,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  94%|█████████▍| 485/516 [07:28<00:29,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  94%|█████████▍| 486/516 [07:29<00:27,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  94%|█████████▍| 487/516 [07:30<00:26,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  95%|█████████▍| 488/516 [07:31<00:25,  1.08it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  95%|█████████▍| 489/516 [07:32<00:24,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  95%|█████████▍| 490/516 [07:33<00:23,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  95%|█████████▌| 491/516 [07:34<00:22,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  95%|█████████▌| 492/516 [07:34<00:22,  1.09it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  96%|█████████▌| 493/516 [07:35<00:21,  1.06it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  96%|█████████▌| 494/516 [07:36<00:20,  1.07it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  96%|█████████▌| 495/516 [07:37<00:20,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  96%|█████████▌| 496/516 [07:38<00:19,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  96%|█████████▋| 497/516 [07:39<00:18,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  97%|█████████▋| 498/516 [07:40<00:17,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  97%|█████████▋| 499/516 [07:41<00:16,  1.04it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  97%|█████████▋| 500/516 [07:42<00:15,  1.02it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  97%|█████████▋| 501/516 [07:43<00:14,  1.01it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  97%|█████████▋| 502/516 [07:44<00:13,  1.01it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  97%|█████████▋| 503/516 [07:45<00:12,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  98%|█████████▊| 504/516 [07:46<00:11,  1.04it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  98%|█████████▊| 505/516 [07:47<00:10,  1.02it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  98%|█████████▊| 506/516 [07:48<00:09,  1.04it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  98%|█████████▊| 507/516 [07:49<00:08,  1.02it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  98%|█████████▊| 508/516 [07:50<00:07,  1.02it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  99%|█████████▊| 509/516 [07:51<00:06,  1.01it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  99%|█████████▉| 510/516 [07:52<00:05,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  99%|█████████▉| 511/516 [07:53<00:04,  1.04it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  99%|█████████▉| 512/516 [07:54<00:03,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates:  99%|█████████▉| 513/516 [07:55<00:02,  1.03it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates: 100%|█████████▉| 514/516 [07:56<00:01,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   self._init_dates(dates, freq)
# Processing dates: 100%|█████████▉| 515/516 [07:57<00:00,  1.05it/s]C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\NicholasRatti\AppData\Local\Temp\ipykernel_17212\1150266332.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[next_date] = np.nan  # Initialize with NaNs
# Processing dates: 100%|██████████| 516/516 [07:58<00:00,  1.08it/s]
#             Index_Returns  Recursive_Predictions  \
# Date
# 2015-01-04      -0.006506                    NaN
# 2015-01-11      -0.012417                    0.0
# 2015-01-18       0.016044                    0.0
# 2015-01-25      -0.027697                    0.0
# 2015-02-01       0.030316                    0.0
#
#            Recursive_Predicted_Regime_Label
# Date
# 2015-01-04                              NaN
# 2015-01-11                   Low Volatility
# 2015-01-18                   Low Volatility
# 2015-01-25                   Low Volatility
# 2015-02-01                   Low Volatility

# %%
# # Loop over the test dates, including the last date
# test_dates = test.index
# for i, date in enumerate(test_dates):
#     # Expand the training data to include up to the current date
#     recursive_train = data.loc[data.index <= date, 'Index_Returns']

#     # Fit the Markov Switching Model on the expanded training data
#     recursive_model = MarkovRegression(recursive_train, k_regimes=2, trend='c', switching_variance=True)
#     try:
#         recursive_result = recursive_model.fit(disp=False)
#     except Exception as e:
#         print(f"Model failed to converge at date {date}: {e}")
#         continue  # Skip this date if the model fails to fit

#     # Extract smoothed probabilities and last known state probabilities
#     smoothed_probs = recursive_result.smoothed_marginal_probabilities
#     last_probs = smoothed_probs.iloc[-1].values

#     # Extract transition probabilities from the model parameters
#     params = recursive_result.params
#     p_00 = params['p[0->0]']
#     p_10 = params['p[1->0]']
#     p_01 = 1 - p_00
#     p_11 = 1 - p_10

#     # Construct the transition matrix
#     transition_matrix = np.array([
#         [p_00, p_01],
#         [p_10, p_11]
#     ])

#     # Update state probabilities to predict the next day's regime
#     state_probs = np.dot(last_probs, transition_matrix)

#     # Determine the most likely regime at t+1
#     regime_labels = smoothed_probs.columns.tolist()  # Should be [0, 1]
#     most_likely_regime = regime_labels[np.argmax(state_probs)]

#     # Get the next date for prediction
#     if i + 1 < len(test.index):
#         next_date = test.index[i + 1]
#     else:
#         # Predicting beyond the available data; estimate next date
#         next_date = date + pd.Timedelta(days=1)
#         # Add next_date to the DataFrame if it doesn't exist
#         if next_date not in data.index:
#             data.loc[next_date] = np.nan  # Initialize with NaNs

#     # Store the predicted regime in 'Recursive_Predictions' at next_date
#     data.at[next_date, 'Recursive_Predictions'] = most_likely_regime

#     # Determine which regime corresponds to low and high volatility
#     variances = [params['sigma2[0]'], params['sigma2[1]']]
#     sigma2_0 = variances[0]
#     sigma2_1 = variances[1]

#     if sigma2_0 < sigma2_1:
#         regime_mapping = {0: 'Low Volatility', 1: 'High Volatility'}
#     else:
#         regime_mapping = {0: 'High Volatility', 1: 'Low Volatility'}

#     # Map the predicted regime to labels
#     predicted_label = regime_mapping[most_likely_regime]
#     data.at[next_date, 'Recursive_Predicted_Regime_Label'] = predicted_label

# # Display the recursive predictions
# print(data.loc[test.index, ['Index_Returns', 'Recursive_Predictions', 'Recursive_Predicted_Regime_Label']].head())

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime  \
# Date
# 1950-01-08    16.650000      -0.025746              0.0
# 1950-01-15    16.940001       0.017417              0.0
# 1950-01-22    16.900000      -0.002361              0.0
# 1950-01-29    17.350000       0.026627              0.0
# 1950-02-05    17.209999      -0.008069              0.0
# ...                 ...            ...              ...
# 2024-10-27  5728.799805      -0.013657              NaN
# 2024-11-03  5995.540039       0.046561              NaN
# 2024-11-10  5985.379883      -0.001695              NaN
# 2024-11-13  5985.379883       0.000000              NaN
# 2024-11-14          NaN            NaN              NaN
#
#             Recursive_Predictions Recursive_Predicted_Regime_Label
# Date
# 1950-01-08                    NaN                              NaN
# 1950-01-15                    NaN                              NaN
# 1950-01-22                    NaN                              NaN
# 1950-01-29                    NaN                              NaN
# 1950-02-05                    NaN                              NaN
# ...                           ...                              ...
# 2024-10-27                    0.0                   Low Volatility
# 2024-11-03                    0.0                   Low Volatility
# 2024-11-10                    0.0                   Low Volatility
# 2024-11-13                    0.0                   Low Volatility
# 2024-11-14                    0.0                   Low Volatility
#
# [3908 rows x 5 columns]

# %%
# Check for NaNs in 'Index_Returns' and drop them
returns = data['Index_Returns'].dropna()

# Fit Markov Switching Model
model = MarkovRegression(returns, k_regimes=2, trend='c', switching_variance=True)
result = model.fit()
print(result.summary())

# Add regime to the data
data.loc[returns.index, 'Full_Vol_Regime'] = result.smoothed_marginal_probabilities.idxmax(axis=1)
# Out:
# C:\Users\NicholasRatti\anaconda3\envs\msm_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          Index_Returns   No. Observations:                 3907
# Model:               MarkovRegression   Log Likelihood                9972.114
# Date:                Thu, 14 Nov 2024   AIC                         -19932.228
# Time:                        08:23:47   BIC                         -19894.605
# Sample:                             0   HQIC                        -19918.876
#                                - 3907
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.000      9.784      0.000       0.002       0.003
# sigma2         0.0002   8.12e-06     26.284      0.000       0.000       0.000
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.001     -1.594      0.111      -0.004       0.000
# sigma2         0.0012   7.89e-05     14.762      0.000       0.001       0.001
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9791      0.004    239.565      0.000       0.971       0.987
# p[1->0]        0.0671      0.014      4.740      0.000       0.039       0.095
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime  \
# Date
# 1950-01-08    16.650000      -0.025746              0.0
# 1950-01-15    16.940001       0.017417              0.0
# 1950-01-22    16.900000      -0.002361              0.0
# 1950-01-29    17.350000       0.026627              0.0
# 1950-02-05    17.209999      -0.008069              0.0
# ...                 ...            ...              ...
# 2024-10-27  5728.799805      -0.013657              NaN
# 2024-11-03  5995.540039       0.046561              NaN
# 2024-11-10  5985.379883      -0.001695              NaN
# 2024-11-13  5985.379883       0.000000              NaN
# 2024-11-14          NaN            NaN              NaN
#
#             Recursive_Predictions Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-08                    NaN                              NaN
# 1950-01-15                    NaN                              NaN
# 1950-01-22                    NaN                              NaN
# 1950-01-29                    NaN                              NaN
# 1950-02-05                    NaN                              NaN
# ...                           ...                              ...
# 2024-10-27                    0.0                   Low Volatility
# 2024-11-03                    0.0                   Low Volatility
# 2024-11-10                    0.0                   Low Volatility
# 2024-11-13                    0.0                   Low Volatility
# 2024-11-14                    0.0                   Low Volatility
#
#             Full_Vol_Regime
# Date
# 1950-01-08              0.0
# 1950-01-15              0.0
# 1950-01-22              0.0
# 1950-01-29              0.0
# 1950-02-05              0.0
# ...                     ...
# 2024-10-27              0.0
# 2024-11-03              0.0
# 2024-11-10              0.0
# 2024-11-13              0.0
# 2024-11-14              NaN
#
# [3908 rows x 6 columns]

# %%
# Non-Recursive Non-Updating Parameter Set

# Extract the smoothed probabilities for the training data
smoothed_probs = train_result.smoothed_marginal_probabilities

# Extract the last known state probabilities (at the end of the training data)
last_probs = smoothed_probs.iloc[-1].values  # Convert to NumPy array

# Regime labels (from smoothed probabilities)
regime_labels = smoothed_probs.columns.tolist()  # Should be [0, 1]

# Extract transition probabilities from the model parameters
params = train_result.params

# Transition probabilities
p_00 = params['p[0->0]']  # Probability of staying in Regime 0
p_10 = params['p[1->0]']  # Probability of moving from Regime 1 to Regime 0

# Probabilities of transitioning to Regime 1
p_01 = 1 - p_00           # Probability of moving from Regime 0 to Regime 1
p_11 = 1 - p_10           # Probability of staying in Regime 1

# Construct the transition matrix
transition_matrix = np.array([
    [p_00, p_01],  # Transitions from Regime 0
    [p_10, p_11]   # Transitions from Regime 1
])

# Regime-specific variances
variances = [params['sigma2[0]'], params['sigma2[1]']]

# Initialize columns for state probabilities and predicted regime in the data DataFrame
data['State_Prob_Regime0'] = np.nan
data['State_Prob_Regime1'] = np.nan
data['Predicted_Regime'] = np.nan

# Initialize state probabilities with the last known probabilities from the training data
state_probs = last_probs.copy()

# Loop over each date in the test set within the data DataFrame
for date in test.index:
    # Update state probabilities using the transition matrix
    state_probs = np.dot(state_probs, transition_matrix)
    
    # Store the state probabilities in the DataFrame
    data.at[date, 'State_Prob_Regime0'] = state_probs[0]
    data.at[date, 'State_Prob_Regime1'] = state_probs[1]
    
    # Determine the most likely regime
    most_likely_regime = regime_labels[np.argmax(state_probs)]
    
    # Store the predicted regime in the DataFrame
    data.at[date, 'Predicted_Regime'] = most_likely_regime

# Determine which regime corresponds to low volatility and high volatility
sigma2_0 = variances[0]
sigma2_1 = variances[1]

if sigma2_0 < sigma2_1:
    regime_mapping = {0: 'Low Volatility', 1: 'High Volatility'}
else:
    regime_mapping = {0: 'High Volatility', 1: 'Low Volatility'}

# Map the predicted regimes to labels
data['Predicted_Regime_Label'] = data['Predicted_Regime'].map(regime_mapping)

# # Display the first few rows of the data DataFrame for the test period
# print(data.loc[test.index, ['Index_Returns', 'State_Prob_Regime0', 'State_Prob_Regime1', 'Predicted_Regime', 'Predicted_Regime_Label']].head())
# Create the 'Blended_Test_Training_Regime' by merging 'Training Regime' and 'Predicted_Regime' based on date condition
data['Blended_Test_Training_Regime'] = None  # Initialize the column with None

# Set values from 'Training Regime' for dates before split_date
data.loc[data.index < split_date, 'Blended_Test_Training_Regime'] = data['Training Regime']

# Set values from 'Predicted_Regime' for dates on or after split_date
data.loc[data.index >= split_date, 'Blended_Test_Training_Regime'] = data['Predicted_Regime']

# Display the DataFrame with the new 'Blended_Test_Training_Regime' column
print(data[['Training Regime', 'Predicted_Regime', 'Blended_Test_Training_Regime']])
# Out:
#             Training Regime  Predicted_Regime Blended_Test_Training_Regime
# Date
# 1950-01-08              0.0               NaN                          0.0
# 1950-01-15              0.0               NaN                          0.0
# 1950-01-22              0.0               NaN                          0.0
# 1950-01-29              0.0               NaN                          0.0
# 1950-02-05              0.0               NaN                          0.0
# ...                     ...               ...                          ...
# 2024-10-27              NaN               0.0                          0.0
# 2024-11-03              NaN               0.0                          0.0
# 2024-11-10              NaN               0.0                          0.0
# 2024-11-13              NaN               0.0                          0.0
# 2024-11-14              NaN               NaN                          NaN
#
# [3908 rows x 3 columns]

# %%
data
# Out:
#               Adj_Close  Index_Returns  Training Regime  \
# Date
# 1950-01-08    16.650000      -0.025746              0.0
# 1950-01-15    16.940001       0.017417              0.0
# 1950-01-22    16.900000      -0.002361              0.0
# 1950-01-29    17.350000       0.026627              0.0
# 1950-02-05    17.209999      -0.008069              0.0
# ...                 ...            ...              ...
# 2024-10-27  5728.799805      -0.013657              NaN
# 2024-11-03  5995.540039       0.046561              NaN
# 2024-11-10  5985.379883      -0.001695              NaN
# 2024-11-13  5985.379883       0.000000              NaN
# 2024-11-14          NaN            NaN              NaN
#
#             Recursive_Predictions Recursive_Predicted_Regime_Label  \
# Date
# 1950-01-08                    NaN                              NaN
# 1950-01-15                    NaN                              NaN
# 1950-01-22                    NaN                              NaN
# 1950-01-29                    NaN                              NaN
# 1950-02-05                    NaN                              NaN
# ...                           ...                              ...
# 2024-10-27                    0.0                   Low Volatility
# 2024-11-03                    0.0                   Low Volatility
# 2024-11-10                    0.0                   Low Volatility
# 2024-11-13                    0.0                   Low Volatility
# 2024-11-14                    0.0                   Low Volatility
#
#             Full_Vol_Regime  State_Prob_Regime0  State_Prob_Regime1  \
# Date
# 1950-01-08              0.0                 NaN                 NaN
# 1950-01-15              0.0                 NaN                 NaN
# 1950-01-22              0.0                 NaN                 NaN
# 1950-01-29              0.0                 NaN                 NaN
# 1950-02-05              0.0                 NaN                 NaN
# ...                     ...                 ...                 ...
# 2024-10-27              0.0            0.760073            0.239927
# 2024-11-03              0.0            0.760073            0.239927
# 2024-11-10              0.0            0.760073            0.239927
# 2024-11-13              0.0            0.760073            0.239927
# 2024-11-14              NaN                 NaN                 NaN
#
#             Predicted_Regime Predicted_Regime_Label  \
# Date
# 1950-01-08               NaN                    NaN
# 1950-01-15               NaN                    NaN
# 1950-01-22               NaN                    NaN
# 1950-01-29               NaN                    NaN
# 1950-02-05               NaN                    NaN
# ...                      ...                    ...
# 2024-10-27               0.0         Low Volatility
# 2024-11-03               0.0         Low Volatility
# 2024-11-10               0.0         Low Volatility
# 2024-11-13               0.0         Low Volatility
# 2024-11-14               NaN                    NaN
#
#            Blended_Test_Training_Regime
# Date
# 1950-01-08                          0.0
# 1950-01-15                          0.0
# 1950-01-22                          0.0
# 1950-01-29                          0.0
# 1950-02-05                          0.0
# ...                                 ...
# 2024-10-27                          0.0
# 2024-11-03                          0.0
# 2024-11-10                          0.0
# 2024-11-13                          0.0
# 2024-11-14                          NaN
#
# [3908 rows x 11 columns]

# %%
# Flatten MultiIndex columns if necessary
if isinstance(data.columns, pd.MultiIndex):
    data.columns = ['_'.join(filter(None, col)) for col in data.columns]

# Specify the database filename
db_filename = 'output/fill_forward_comparison.db'

# Connect to the SQLite database
conn = sqlite3.connect(db_filename)

# Table name for main data export
table_name = 'regime_data'

# Write the flattened DataFrame to the SQLite database
data.to_sql(table_name, conn, if_exists='replace', index=True)

# Verify the table structure after export
cursor = conn.cursor()
cursor.execute(f"PRAGMA table_info({table_name})")
schema = cursor.fetchall()
print("Table schema:", schema)

# Close the connection
conn.close()
# Out:
# Table schema: [(0, 'Date', 'TIMESTAMP', 0, None, 0), (1, 'Adj_Close', 'REAL', 0, None, 0), (2, 'Index_Returns', 'REAL', 0, None, 0), (3, 'Training Regime', 'REAL', 0, None, 0), (4, 'Recursive_Predictions', 'REAL', 0, None, 0), (5, 'Recursive_Predicted_Regime_Label', 'TEXT', 0, None, 0), (6, 'Full_Vol_Regime', 'REAL', 0, None, 0), (7, 'State_Prob_Regime0', 'REAL', 0, None, 0), (8, 'State_Prob_Regime1', 'REAL', 0, None, 0), (9, 'Predicted_Regime', 'REAL', 0, None, 0), (10, 'Predicted_Regime_Label', 'TEXT', 0, None, 0), (11, 'Blended_Test_Training_Regime', 'REAL', 0, None, 0)]

# %%
# Filter for rows where 'Recursive_Predictions' and 'Full_Vol_Regime' do not match, excluding NaNs
filtered_data = data[(data['Recursive_Predictions'] != data['Full_Vol_Regime'])].dropna(subset=['Recursive_Predictions', 'Full_Vol_Regime'])

# Flatten MultiIndex columns if necessary
if isinstance(filtered_data.columns, pd.MultiIndex):
    filtered_data.columns = ['_'.join(filter(None, col)) for col in filtered_data.columns]

# Connect to the SQLite database
conn = sqlite3.connect(db_filename)

# Table name for filtered data
new_table_name = 'mismatched_regimes'

# Write the filtered DataFrame to the SQLite database
filtered_data.to_sql(new_table_name, conn, if_exists='replace', index=True)

# Verify the table structure for the filtered data
cursor = conn.cursor()
cursor.execute(f"PRAGMA table_info({new_table_name})")
filtered_schema = cursor.fetchall()
print("Filtered Table schema:", filtered_schema)

# Close the connection
conn.close()
# Out:
# Filtered Table schema: [(0, 'Date', 'TIMESTAMP', 0, None, 0), (1, 'Adj_Close', 'REAL', 0, None, 0), (2, 'Index_Returns', 'REAL', 0, None, 0), (3, 'Training Regime', 'REAL', 0, None, 0), (4, 'Recursive_Predictions', 'REAL', 0, None, 0), (5, 'Recursive_Predicted_Regime_Label', 'TEXT', 0, None, 0), (6, 'Full_Vol_Regime', 'REAL', 0, None, 0), (7, 'State_Prob_Regime0', 'REAL', 0, None, 0), (8, 'State_Prob_Regime1', 'REAL', 0, None, 0), (9, 'Predicted_Regime', 'REAL', 0, None, 0), (10, 'Predicted_Regime_Label', 'TEXT', 0, None, 0), (11, 'Blended_Test_Training_Regime', 'REAL', 0, None, 0)]

# %%
# Connect to the SQLite database
conn = sqlite3.connect(db_filename)

# Retrieve the main data table
query = "SELECT * FROM regime_data"
df_main = pd.read_sql_query(query, conn)

# Export the main data to CSV
output_csv_path_main = 'output/regime_data_export.csv'
df_main.to_csv(output_csv_path_main, index=False)
print(f"Main data exported to {output_csv_path_main}")

# Retrieve the filtered data table
query_filtered = "SELECT * FROM mismatched_regimes"
df_filtered = pd.read_sql_query(query_filtered, conn)

# Export the filtered data to CSV
output_csv_path_filtered = 'output/mismatched_regimes_export.csv'
df_filtered.to_csv(output_csv_path_filtered, index=False)
print(f"Filtered data exported to {output_csv_path_filtered}")

# Close the connection
conn.close()
# Out:
# Main data exported to output/regime_data_export.csv
# Filtered data exported to output/mismatched_regimes_export.csv
